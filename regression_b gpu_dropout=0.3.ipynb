# %%
from sklearn.preprocessing import StandardScaler, LabelBinarizer 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.linalg import svd
from sklearn.linear_model import Ridge, LogisticRegression, LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from toolbox_02450 import rlr_validate
from matplotlib.pylab import (figure, semilogx, loglog, xlabel, ylabel, legend, title, subplot, show, grid)
from scipy.io import loadmat
import sklearn.linear_model as lm
from sklearn import model_selection
import torch
from toolbox_02450 import train_neural_net, draw_neural_net, visualize_decision_boundary, rlr_validate_mse, rlr_validate_nmo, mcnemar, ttest_twomodels
from scipy import stats
import statsmodels.stats.contingency_tables as tbl
from collections import Counter
import torch.optim as optim
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  
plt.rcParams['axes.unicode_minus'] = False  # display “ - ”


data = pd.read_csv('dropout_data.csv', delimiter=';')
data.columns = [col.replace('\t', '') for col in data.columns]
# data_no_target = data.drop(columns=['Target']) # delete target column
# data_matrix = data_no_target.values  # data matrix
# target = data['Target']
# attributeNames = data_no_target.columns.tolist()
# classNames = target.unique().tolist()
# class_num = len(classNames)
# class_name_mapping = {className: index for index, className in enumerate(classNames)}
# target_to_num = [class_name_mapping[className] for className in target] # drop out = 0, graduate = 1, enrolled = 2
# one_hot_encoded = LabelBinarizer().fit_transform(target_to_num)

# # revise partial data according to appendix of reference
# for col_index in [0,1,3,5,7,8,9,10,11]:
#         current_column = data_matrix[:, col_index]
#         unique_values = np.unique(current_column)
#         unique_values.sort()
#         value_to_rank = {value: rank +1 for rank, value in enumerate(unique_values)}
#         data_matrix[:, col_index] = np.vectorize(value_to_rank.get)(current_column)

# revise partial data according to appendix of reference
for col_index in [0,1,3,5,6,7,8,9]:
        current_column = data.values[:, col_index]
        unique_values = np.unique(current_column)
        unique_values.sort()
        value_to_rank = {value: rank +1 for rank, value in enumerate(unique_values)}
        data.values[:, col_index] = np.vectorize(value_to_rank.get)(current_column)



features = data.drop(columns=['Target', 'Previous qualification (grade)', 'Admission grade'])
y = data['Previous qualification (grade)'].values
X = features.values  # Data matrix
attributeNames = features.columns.tolist()

# Normalize data
# X = stats.zscore(X)
# X = data_matrix
# y = X[:, 6]
# X = np.delete(X, 6, axis=1)
# X = np.delete(X, 11, axis=1)
# attributeNames.remove('Previous qualification (grade)')
###############
# regression_b#
###############

# %%
N, M = X.shape
# Add offset attribute
X = np.concatenate((np.ones((X.shape[0],1)),X),1)
attributeNames = [u'Offset']+attributeNames
M = M+1
K = 10
CV = model_selection.KFold(K, shuffle=True)
Error_train = np.empty((K,1))
Error_test = np.empty((K,1))
Error_train_rlr = np.empty((K,1))
Error_test_rlr = np.empty((K,1))
Error_train_nofeatures = np.empty((K,1))
Error_test_nofeatures = np.empty((K,1))
w_rlr = np.empty((M,K))
mu = np.empty((K, M-1))
sigma = np.empty((K, M-1))
w_noreg = np.empty((M,K))
k=0

z_al_r = []
CI_al_r = []
p_al_r = []

z_ab_r = []
CI_ab_r = []
p_ab_r = []

z_lb_r = []
CI_lb_r = []
p_lb_r = []

for train_index, test_index in CV.split(X,y):
    print('\n ***Outer Crossvalidation fold: {0}/{1}'.format(k+1,K))
    # extract training and test set for current CV fold
    X_train = X[train_index]
    y_train = y[train_index]
    X_test = X[test_index]
    y_test = y[test_index]
    internal_cross_validation = 10
    lambdas = np.logspace(-8, 8, 100)

    # receive output
    opt_val_err, opt_lambda, mean_w_vs_lambda, train_err_vs_lambda, test_err_vs_lambda, baseline_mse, best_units_num, min_error_ann = rlr_validate_mse(X_train, y_train, lambdas, internal_cross_validation)

    # Standardize outer fold based on training set, and save the mean and standard
    # deviations since they're part of the model (they would be needed for
    # making new predictions) - for brevity we won't always store these in the scripts
    mu[k, :] = np.mean(X_train[:, 1:], 0)
    sigma[k, :] = np.std(X_train[:, 1:], 0)
    
    X_train[:, 1:] = (X_train[:, 1:] - mu[k, :] ) / sigma[k, :] 
    X_test[:, 1:] = (X_test[:, 1:] - mu[k, :] ) / sigma[k, :]
    device = torch.device('cuda:0')
    
    X_train_ann = torch.Tensor(X_train).to(device)
    y_train_ann = torch.Tensor(y_train).to(device)
    X_test_ann = torch.Tensor(X_test).to(device)
    y_test_ann = torch.Tensor(y_test).to(device)
    y_train_ann = y_train_ann.view(-1,1).to(device)
    y_test_ann = y_test_ann.view(-1,1).to(device)
    

    # ANN
    model = torch.nn.Sequential(
        torch.nn.Linear(M, best_units_num),  # M features to H hidden units
        torch.nn.BatchNorm1d(best_units_num),
        torch.nn.ReLU(),
        torch.nn.Dropout(p=0.3),
        torch.nn.Linear(best_units_num, 1),  # H hidden units to 1 output neuron for regression
    ).to(device)
    loss_fn = torch.nn.MSELoss()
    loss_fn = loss_fn.to(device)
    optimizer = optim.Adam(model.parameters(), weight_decay= 0.0005)
    max_iter = 4000
    for iteration in range(max_iter):
        X_batch = X_train_ann
        y_batch = y_train_ann
        predictions = model(X_batch)
        loss = loss_fn(predictions, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    y_test_est_ann = model(X_test_ann).float()
    y_test_ann = y_test_ann
    y_test_est_ann = y_test_est_ann
    error_ann = ((y_test_ann - y_test_est_ann) ** 2).mean()
    
    # Linear Regression
    Xty = X_train.T @ y_train
    XtX = X_train.T @ X_train
    lambdaI = opt_lambda * np.eye(M)
    lambdaI[0,0] = 0 # Do no regularize the bias term
    w_rlr[:,k] = np.linalg.solve(XtX+lambdaI,Xty).squeeze()
    y_test_pred = X_test @ w_rlr[:,k].T
    error_lr = ((y_test - y_test_pred) ** 2).mean().item()
    
    # Baseline
    y_mean_train = np.mean(y_train)
    y_pred_baseline = np.full(len(y_test), y_mean_train)
    error_bl = np.mean((y_pred_baseline - y_test) ** 2)
    
    
    # calculate t-test
    z_al, CI_al, p_al = ttest_twomodels(y_test, y_test_est_ann.cpu().data.numpy(), y_test_pred, alpha=0.05, loss_norm_p=1)
    z_ab, CI_ab, p_ab = ttest_twomodels(y_test, y_test_est_ann.cpu().data.numpy(), y_pred_baseline, alpha=0.05, loss_norm_p=1)
    z_lb, CI_lb, p_lb = ttest_twomodels(y_test, y_test_pred, y_pred_baseline, alpha=0.05, loss_norm_p=1)

    z_al_r.append(z_al)
    CI_al_1  = [arr[0] for arr in CI_al] # extract repeated 2 elements
    CI_al_r.append(CI_al_1)
    p_al_r.append(np.mean(p_al))
    
    z_ab_r.append(z_ab)
    CI_ab_1  = [arr[0] for arr in CI_ab] # extract repeated 2 elements
    CI_ab_r.append(CI_ab_1)
    p_ab_r.append(np.mean(p_ab))
    
    z_lb_r.append(z_lb)
    #CI_lb_1  = [arr[0] for arr in CI_lb] # extract repeated 2 elements
    CI_lb_r.append(CI_lb)
    p_lb_r.append(np.mean(p_lb))
    
    print('\n',
        'Optimal Hidden units: {0}'.format(best_units_num), '\n',
        # 'ANN error: {0}'.format(np.mean(min_error_ann)), '\n',
        'ANN error: {0}'.format(error_ann), '\n',
        'Optimal λ: {0}'.format(np.log10(opt_lambda)), '\n',
        'Linear Regression error: {0}'.format(error_lr), '\n',
        'Baseline error: {0}'.format(error_bl), '\n',
        #'Test error without: {0}'.format(Error_test.mean()),'\n',
        #'Test error: {0}'.format(Error_test_rlr.mean()), '\n',        
        )

    k+=1
    
###########################
# regression_b_evaluation #
###########################
# Out:
#  ***Outer Crossvalidation fold: 1/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11741.3447265625
#
# hidden units number: 8
#
# 	ANN loss: 839.5812377929688
#
# hidden units number: 16
#
# 	ANN loss: 176.04934692382812
#
# hidden units number: 32
#
# 	ANN loss: 161.1959991455078
#
# hidden units number: 64
#
# 	ANN loss: 157.4563751220703
#
# hidden units number: 128
#
# 	ANN loss: 159.3373260498047
#
# hidden units number: 256
#
# 	ANN loss: 163.27183532714844
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 12198.4267578125
#
# hidden units number: 8
#
# 	ANN loss: 1387.4046630859375
#
# hidden units number: 16
#
# 	ANN loss: 182.43368530273438
#
# hidden units number: 32
#
# 	ANN loss: 162.9502410888672
#
# hidden units number: 64
#
# 	ANN loss: 163.9185333251953
#
# hidden units number: 128
#
# 	ANN loss: 169.53887939453125
#
# hidden units number: 256
#
# 	ANN loss: 174.2417755126953
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 17072.611328125
#
# hidden units number: 8
#
# 	ANN loss: 2386.01904296875
#
# hidden units number: 16
#
# 	ANN loss: 154.6458282470703
#
# hidden units number: 32
#
# 	ANN loss: 147.5266571044922
#
# hidden units number: 64
#
# 	ANN loss: 150.4100341796875
#
# hidden units number: 128
#
# 	ANN loss: 150.3556671142578
#
# hidden units number: 256
#
# 	ANN loss: 159.5302734375
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 12067.0009765625
#
# hidden units number: 8
#
# 	ANN loss: 1594.5379638671875
#
# hidden units number: 16
#
# 	ANN loss: 193.19287109375
#
# hidden units number: 32
#
# 	ANN loss: 160.73910522460938
#
# hidden units number: 64
#
# 	ANN loss: 163.57318115234375
#
# hidden units number: 128
#
# 	ANN loss: 159.7908477783203
#
# hidden units number: 256
#
# 	ANN loss: 165.75904846191406
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 17241.958984375
#
# hidden units number: 8
#
# 	ANN loss: 632.7232055664062
#
# hidden units number: 16
#
# 	ANN loss: 177.98001098632812
#
# hidden units number: 32
#
# 	ANN loss: 159.80812072753906
#
# hidden units number: 64
#
# 	ANN loss: 163.27947998046875
#
# hidden units number: 128
#
# 	ANN loss: 165.6990203857422
#
# hidden units number: 256
#
# 	ANN loss: 166.85760498046875
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 11713.404296875
#
# hidden units number: 8
#
# 	ANN loss: 1004.8556518554688
#
# hidden units number: 16
#
# 	ANN loss: 195.69149780273438
#
# hidden units number: 32
#
# 	ANN loss: 177.07066345214844
#
# hidden units number: 64
#
# 	ANN loss: 176.0546875
#
# hidden units number: 128
#
# 	ANN loss: 183.76016235351562
#
# hidden units number: 256
#
# 	ANN loss: 183.96226501464844
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 11897.17578125
#
# hidden units number: 8
#
# 	ANN loss: 996.6370239257812
#
# hidden units number: 16
#
# 	ANN loss: 213.29022216796875
#
# hidden units number: 32
#
# 	ANN loss: 188.51629638671875
#
# hidden units number: 64
#
# 	ANN loss: 188.56451416015625
#
# hidden units number: 128
#
# 	ANN loss: 187.94805908203125
#
# hidden units number: 256
#
# 	ANN loss: 188.34017944335938
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 16764.15625
#
# hidden units number: 8
#
# 	ANN loss: 1334.527587890625
#
# hidden units number: 16
#
# 	ANN loss: 195.71128845214844
#
# hidden units number: 32
#
# 	ANN loss: 155.53659057617188
#
# hidden units number: 64
#
# 	ANN loss: 150.37022399902344
#
# hidden units number: 128
#
# 	ANN loss: 154.17100524902344
#
# hidden units number: 256
#
# 	ANN loss: 152.44358825683594
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 16726.26171875
#
# hidden units number: 8
#
# 	ANN loss: 2194.1455078125
#
# hidden units number: 16
#
# 	ANN loss: 165.99691772460938
#
# hidden units number: 32
#
# 	ANN loss: 157.46400451660156
#
# hidden units number: 64
#
# 	ANN loss: 164.24801635742188
#
# hidden units number: 128
#
# 	ANN loss: 169.3339385986328
#
# hidden units number: 256
#
# 	ANN loss: 175.30755615234375
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 12374.0537109375
#
# hidden units number: 8
#
# 	ANN loss: 2205.34765625
#
# hidden units number: 16
#
# 	ANN loss: 170.6808624267578
#
# hidden units number: 32
#
# 	ANN loss: 150.97579956054688
#
# hidden units number: 64
#
# 	ANN loss: 149.9622802734375
#
# hidden units number: 128
#
# 	ANN loss: 153.5010528564453
#
# hidden units number: 256
#
# 	ANN loss: 157.72775268554688
#
#
#  Optimal Hidden units: 32
#  ANN error: 165.27825927734375
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 166.88219855667907
#  Baseline error: 168.891997136697
#
#
#  ***Outer Crossvalidation fold: 2/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11612.787109375
#
# hidden units number: 8
#
# 	ANN loss: 850.9219970703125
#
# hidden units number: 16
#
# 	ANN loss: 186.1845245361328
#
# hidden units number: 32
#
# 	ANN loss: 176.85752868652344
#
# hidden units number: 64
#
# 	ANN loss: 175.59825134277344
#
# hidden units number: 128
#
# 	ANN loss: 190.5724334716797
#
# hidden units number: 256
#
# 	ANN loss: 196.2790985107422
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 17232.5
#
# hidden units number: 8
#
# 	ANN loss: 567.7681274414062
#
# hidden units number: 16
#
# 	ANN loss: 189.14984130859375
#
# hidden units number: 32
#
# 	ANN loss: 168.65805053710938
#
# hidden units number: 64
#
# 	ANN loss: 167.44911193847656
#
# hidden units number: 128
#
# 	ANN loss: 170.9440155029297
#
# hidden units number: 256
#
# 	ANN loss: 169.63560485839844
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 11556.2275390625
#
# hidden units number: 8
#
# 	ANN loss: 749.7528076171875
#
# hidden units number: 16
#
# 	ANN loss: 152.87071228027344
#
# hidden units number: 32
#
# 	ANN loss: 136.09921264648438
#
# hidden units number: 64
#
# 	ANN loss: 141.1261444091797
#
# hidden units number: 128
#
# 	ANN loss: 142.39517211914062
#
# hidden units number: 256
#
# 	ANN loss: 143.75535583496094
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 11999.1787109375
#
# hidden units number: 8
#
# 	ANN loss: 647.582763671875
#
# hidden units number: 16
#
# 	ANN loss: 178.9723663330078
#
# hidden units number: 32
#
# 	ANN loss: 159.95416259765625
#
# hidden units number: 64
#
# 	ANN loss: 154.13577270507812
#
# hidden units number: 128
#
# 	ANN loss: 157.5165252685547
#
# hidden units number: 256
#
# 	ANN loss: 162.37173461914062
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 16780.890625
#
# hidden units number: 8
#
# 	ANN loss: 938.1149291992188
#
# hidden units number: 16
#
# 	ANN loss: 169.4606170654297
#
# hidden units number: 32
#
# 	ANN loss: 148.2374725341797
#
# hidden units number: 64
#
# 	ANN loss: 147.79725646972656
#
# hidden units number: 128
#
# 	ANN loss: 150.3838348388672
#
# hidden units number: 256
#
# 	ANN loss: 153.86961364746094
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 16852.439453125
#
# hidden units number: 8
#
# 	ANN loss: 1462.5313720703125
#
# hidden units number: 16
#
# 	ANN loss: 183.62222290039062
#
# hidden units number: 32
#
# 	ANN loss: 172.84963989257812
#
# hidden units number: 64
#
# 	ANN loss: 170.08566284179688
#
# hidden units number: 128
#
# 	ANN loss: 175.4765625
#
# hidden units number: 256
#
# 	ANN loss: 176.16262817382812
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 16635.671875
#
# hidden units number: 8
#
# 	ANN loss: 523.3829345703125
#
# hidden units number: 16
#
# 	ANN loss: 193.6344757080078
#
# hidden units number: 32
#
# 	ANN loss: 182.10690307617188
#
# hidden units number: 64
#
# 	ANN loss: 176.71791076660156
#
# hidden units number: 128
#
# 	ANN loss: 178.53179931640625
#
# hidden units number: 256
#
# 	ANN loss: 183.2119903564453
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 17190.529296875
#
# hidden units number: 8
#
# 	ANN loss: 673.58837890625
#
# hidden units number: 16
#
# 	ANN loss: 188.63380432128906
#
# hidden units number: 32
#
# 	ANN loss: 154.31683349609375
#
# hidden units number: 64
#
# 	ANN loss: 155.0858612060547
#
# hidden units number: 128
#
# 	ANN loss: 160.23768615722656
#
# hidden units number: 256
#
# 	ANN loss: 167.932861328125
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 11922.0888671875
#
# hidden units number: 8
#
# 	ANN loss: 2295.7548828125
#
# hidden units number: 16
#
# 	ANN loss: 177.1083526611328
#
# hidden units number: 32
#
# 	ANN loss: 169.46575927734375
#
# hidden units number: 64
#
# 	ANN loss: 163.1500701904297
#
# hidden units number: 128
#
# 	ANN loss: 166.7777099609375
#
# hidden units number: 256
#
# 	ANN loss: 168.1124725341797
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 12517.7724609375
#
# hidden units number: 8
#
# 	ANN loss: 985.5338134765625
#
# hidden units number: 16
#
# 	ANN loss: 195.04852294921875
#
# hidden units number: 32
#
# 	ANN loss: 152.4722442626953
#
# hidden units number: 64
#
# 	ANN loss: 150.25164794921875
#
# hidden units number: 128
#
# 	ANN loss: 155.1339569091797
#
# hidden units number: 256
#
# 	ANN loss: 157.89674377441406
#
#
#  Optimal Hidden units: 64
#  ANN error: 157.0588836669922
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 163.94373266953713
#  Baseline error: 176.2844876263549
#
#
#  ***Outer Crossvalidation fold: 3/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11614.0439453125
#
# hidden units number: 8
#
# 	ANN loss: 511.75994873046875
#
# hidden units number: 16
#
# 	ANN loss: 163.3632049560547
#
# hidden units number: 32
#
# 	ANN loss: 137.49024963378906
#
# hidden units number: 64
#
# 	ANN loss: 136.27481079101562
#
# hidden units number: 128
#
# 	ANN loss: 141.34228515625
#
# hidden units number: 256
#
# 	ANN loss: 143.5336151123047
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 11817.611328125
#
# hidden units number: 8
#
# 	ANN loss: 1587.4481201171875
#
# hidden units number: 16
#
# 	ANN loss: 182.978759765625
#
# hidden units number: 32
#
# 	ANN loss: 171.37445068359375
#
# hidden units number: 64
#
# 	ANN loss: 171.459228515625
#
# hidden units number: 128
#
# 	ANN loss: 172.55648803710938
#
# hidden units number: 256
#
# 	ANN loss: 173.93011474609375
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 17020.32421875
#
# hidden units number: 8
#
# 	ANN loss: 891.073974609375
#
# hidden units number: 16
#
# 	ANN loss: 196.46315002441406
#
# hidden units number: 32
#
# 	ANN loss: 184.88987731933594
#
# hidden units number: 64
#
# 	ANN loss: 182.70481872558594
#
# hidden units number: 128
#
# 	ANN loss: 183.5520477294922
#
# hidden units number: 256
#
# 	ANN loss: 186.3573760986328
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 11625.904296875
#
# hidden units number: 8
#
# 	ANN loss: 914.9888305664062
#
# hidden units number: 16
#
# 	ANN loss: 204.92701721191406
#
# hidden units number: 32
#
# 	ANN loss: 168.5033721923828
#
# hidden units number: 64
#
# 	ANN loss: 167.2210693359375
#
# hidden units number: 128
#
# 	ANN loss: 173.03103637695312
#
# hidden units number: 256
#
# 	ANN loss: 176.8126220703125
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 12752.3193359375
#
# hidden units number: 8
#
# 	ANN loss: 2149.3291015625
#
# hidden units number: 16
#
# 	ANN loss: 204.36598205566406
#
# hidden units number: 32
#
# 	ANN loss: 183.9227294921875
#
# hidden units number: 64
#
# 	ANN loss: 193.2506866455078
#
# hidden units number: 128
#
# 	ANN loss: 199.59349060058594
#
# hidden units number: 256
#
# 	ANN loss: 202.77215576171875
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 12300.841796875
#
# hidden units number: 8
#
# 	ANN loss: 1745.5662841796875
#
# hidden units number: 16
#
# 	ANN loss: 175.72805786132812
#
# hidden units number: 32
#
# 	ANN loss: 144.3508758544922
#
# hidden units number: 64
#
# 	ANN loss: 136.94195556640625
#
# hidden units number: 128
#
# 	ANN loss: 141.73216247558594
#
# hidden units number: 256
#
# 	ANN loss: 142.90248107910156
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 17046.900390625
#
# hidden units number: 8
#
# 	ANN loss: 1003.236328125
#
# hidden units number: 16
#
# 	ANN loss: 191.61036682128906
#
# hidden units number: 32
#
# 	ANN loss: 163.0415802001953
#
# hidden units number: 64
#
# 	ANN loss: 158.97622680664062
#
# hidden units number: 128
#
# 	ANN loss: 160.0509796142578
#
# hidden units number: 256
#
# 	ANN loss: 166.82554626464844
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 11775.658203125
#
# hidden units number: 8
#
# 	ANN loss: 3532.96630859375
#
# hidden units number: 16
#
# 	ANN loss: 164.0872344970703
#
# hidden units number: 32
#
# 	ANN loss: 148.45352172851562
#
# hidden units number: 64
#
# 	ANN loss: 143.77774047851562
#
# hidden units number: 128
#
# 	ANN loss: 147.62803649902344
#
# hidden units number: 256
#
# 	ANN loss: 152.37022399902344
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 12434.03515625
#
# hidden units number: 8
#
# 	ANN loss: 1307.016357421875
#
# hidden units number: 16
#
# 	ANN loss: 158.33206176757812
#
# hidden units number: 32
#
# 	ANN loss: 150.1409149169922
#
# hidden units number: 64
#
# 	ANN loss: 159.48829650878906
#
# hidden units number: 128
#
# 	ANN loss: 161.5374755859375
#
# hidden units number: 256
#
# 	ANN loss: 168.01438903808594
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 11625.3369140625
#
# hidden units number: 8
#
# 	ANN loss: 944.9471435546875
#
# hidden units number: 16
#
# 	ANN loss: 206.34417724609375
#
# hidden units number: 32
#
# 	ANN loss: 168.5487518310547
#
# hidden units number: 64
#
# 	ANN loss: 163.72000122070312
#
# hidden units number: 128
#
# 	ANN loss: 167.55538940429688
#
# hidden units number: 256
#
# 	ANN loss: 179.65577697753906
#
#
#  Optimal Hidden units: 64
#  ANN error: 161.53964233398438
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 166.72564122686234
#  Baseline error: 174.78578303093695
#
#
#  ***Outer Crossvalidation fold: 4/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 16939.490234375
#
# hidden units number: 8
#
# 	ANN loss: 883.8648071289062
#
# hidden units number: 16
#
# 	ANN loss: 173.79641723632812
#
# hidden units number: 32
#
# 	ANN loss: 153.35726928710938
#
# hidden units number: 64
#
# 	ANN loss: 152.0716094970703
#
# hidden units number: 128
#
# 	ANN loss: 150.837646484375
#
# hidden units number: 256
#
# 	ANN loss: 156.15380859375
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 16945.759765625
#
# hidden units number: 8
#
# 	ANN loss: 1007.6414184570312
#
# hidden units number: 16
#
# 	ANN loss: 229.0481719970703
#
# hidden units number: 32
#
# 	ANN loss: 171.65008544921875
#
# hidden units number: 64
#
# 	ANN loss: 174.51773071289062
#
# hidden units number: 128
#
# 	ANN loss: 176.16546630859375
#
# hidden units number: 256
#
# 	ANN loss: 180.86785888671875
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 17170.349609375
#
# hidden units number: 8
#
# 	ANN loss: 1430.2333984375
#
# hidden units number: 16
#
# 	ANN loss: 180.18153381347656
#
# hidden units number: 32
#
# 	ANN loss: 149.48031616210938
#
# hidden units number: 64
#
# 	ANN loss: 141.84585571289062
#
# hidden units number: 128
#
# 	ANN loss: 146.95033264160156
#
# hidden units number: 256
#
# 	ANN loss: 157.57469177246094
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 16700.244140625
#
# hidden units number: 8
#
# 	ANN loss: 1373.017578125
#
# hidden units number: 16
#
# 	ANN loss: 195.3066864013672
#
# hidden units number: 32
#
# 	ANN loss: 160.7416229248047
#
# hidden units number: 64
#
# 	ANN loss: 158.49366760253906
#
# hidden units number: 128
#
# 	ANN loss: 159.91041564941406
#
# hidden units number: 256
#
# 	ANN loss: 165.13165283203125
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 17021.8359375
#
# hidden units number: 8
#
# 	ANN loss: 920.3187866210938
#
# hidden units number: 16
#
# 	ANN loss: 172.86785888671875
#
# hidden units number: 32
#
# 	ANN loss: 151.2583465576172
#
# hidden units number: 64
#
# 	ANN loss: 146.8174285888672
#
# hidden units number: 128
#
# 	ANN loss: 146.7228546142578
#
# hidden units number: 256
#
# 	ANN loss: 153.0375518798828
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 17258.955078125
#
# hidden units number: 8
#
# 	ANN loss: 873.8578491210938
#
# hidden units number: 16
#
# 	ANN loss: 191.84014892578125
#
# hidden units number: 32
#
# 	ANN loss: 170.0755157470703
#
# hidden units number: 64
#
# 	ANN loss: 173.92092895507812
#
# hidden units number: 128
#
# 	ANN loss: 175.95681762695312
#
# hidden units number: 256
#
# 	ANN loss: 178.42660522460938
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 11712.5615234375
#
# hidden units number: 8
#
# 	ANN loss: 888.4381103515625
#
# hidden units number: 16
#
# 	ANN loss: 146.27755737304688
#
# hidden units number: 32
#
# 	ANN loss: 140.24905395507812
#
# hidden units number: 64
#
# 	ANN loss: 135.75892639160156
#
# hidden units number: 128
#
# 	ANN loss: 149.0518341064453
#
# hidden units number: 256
#
# 	ANN loss: 152.4474639892578
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 12580.419921875
#
# hidden units number: 8
#
# 	ANN loss: 569.7155151367188
#
# hidden units number: 16
#
# 	ANN loss: 177.5644989013672
#
# hidden units number: 32
#
# 	ANN loss: 153.2285614013672
#
# hidden units number: 64
#
# 	ANN loss: 154.4976043701172
#
# hidden units number: 128
#
# 	ANN loss: 151.68312072753906
#
# hidden units number: 256
#
# 	ANN loss: 156.32196044921875
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 16930.51953125
#
# hidden units number: 8
#
# 	ANN loss: 831.6747436523438
#
# hidden units number: 16
#
# 	ANN loss: 176.40106201171875
#
# hidden units number: 32
#
# 	ANN loss: 157.1373748779297
#
# hidden units number: 64
#
# 	ANN loss: 161.39254760742188
#
# hidden units number: 128
#
# 	ANN loss: 166.5111846923828
#
# hidden units number: 256
#
# 	ANN loss: 172.26739501953125
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 17396.826171875
#
# hidden units number: 8
#
# 	ANN loss: 1036.9708251953125
#
# hidden units number: 16
#
# 	ANN loss: 218.50416564941406
#
# hidden units number: 32
#
# 	ANN loss: 178.24851989746094
#
# hidden units number: 64
#
# 	ANN loss: 187.0162353515625
#
# hidden units number: 128
#
# 	ANN loss: 186.31187438964844
#
# hidden units number: 256
#
# 	ANN loss: 186.17843627929688
#
#
#  Optimal Hidden units: 32
#  ANN error: 196.23626708984375
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 197.35474236483915
#  Baseline error: 206.3492580335304
#
#
#  ***Outer Crossvalidation fold: 5/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 17351.771484375
#
# hidden units number: 8
#
# 	ANN loss: 927.4428100585938
#
# hidden units number: 16
#
# 	ANN loss: 189.80088806152344
#
# hidden units number: 32
#
# 	ANN loss: 174.82102966308594
#
# hidden units number: 64
#
# 	ANN loss: 171.85025024414062
#
# hidden units number: 128
#
# 	ANN loss: 176.8150177001953
#
# hidden units number: 256
#
# 	ANN loss: 176.6643524169922
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 11842.8544921875
#
# hidden units number: 8
#
# 	ANN loss: 992.0776977539062
#
# hidden units number: 16
#
# 	ANN loss: 189.1641845703125
#
# hidden units number: 32
#
# 	ANN loss: 158.81744384765625
#
# hidden units number: 64
#
# 	ANN loss: 155.33377075195312
#
# hidden units number: 128
#
# 	ANN loss: 147.16708374023438
#
# hidden units number: 256
#
# 	ANN loss: 153.5400848388672
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 16720.92578125
#
# hidden units number: 8
#
# 	ANN loss: 1274.2862548828125
#
# hidden units number: 16
#
# 	ANN loss: 150.83445739746094
#
# hidden units number: 32
#
# 	ANN loss: 142.4794921875
#
# hidden units number: 64
#
# 	ANN loss: 141.86135864257812
#
# hidden units number: 128
#
# 	ANN loss: 150.06503295898438
#
# hidden units number: 256
#
# 	ANN loss: 150.9752960205078
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 16937.783203125
#
# hidden units number: 8
#
# 	ANN loss: 510.4150390625
#
# hidden units number: 16
#
# 	ANN loss: 176.2342529296875
#
# hidden units number: 32
#
# 	ANN loss: 152.79388427734375
#
# hidden units number: 64
#
# 	ANN loss: 155.4720458984375
#
# hidden units number: 128
#
# 	ANN loss: 154.24249267578125
#
# hidden units number: 256
#
# 	ANN loss: 158.92758178710938
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 16840.095703125
#
# hidden units number: 8
#
# 	ANN loss: 904.1703491210938
#
# hidden units number: 16
#
# 	ANN loss: 198.39085388183594
#
# hidden units number: 32
#
# 	ANN loss: 166.68777465820312
#
# hidden units number: 64
#
# 	ANN loss: 166.23275756835938
#
# hidden units number: 128
#
# 	ANN loss: 169.4044189453125
#
# hidden units number: 256
#
# 	ANN loss: 174.58717346191406
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 16924.44140625
#
# hidden units number: 8
#
# 	ANN loss: 800.9024658203125
#
# hidden units number: 16
#
# 	ANN loss: 161.73780822753906
#
# hidden units number: 32
#
# 	ANN loss: 155.2468719482422
#
# hidden units number: 64
#
# 	ANN loss: 152.77349853515625
#
# hidden units number: 128
#
# 	ANN loss: 152.86761474609375
#
# hidden units number: 256
#
# 	ANN loss: 158.34921264648438
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 17298.603515625
#
# hidden units number: 8
#
# 	ANN loss: 1347.0389404296875
#
# hidden units number: 16
#
# 	ANN loss: 206.7772216796875
#
# hidden units number: 32
#
# 	ANN loss: 192.01907348632812
#
# hidden units number: 64
#
# 	ANN loss: 189.6102752685547
#
# hidden units number: 128
#
# 	ANN loss: 185.7786102294922
#
# hidden units number: 256
#
# 	ANN loss: 189.33319091796875
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 17015.880859375
#
# hidden units number: 8
#
# 	ANN loss: 784.3355712890625
#
# hidden units number: 16
#
# 	ANN loss: 158.70147705078125
#
# hidden units number: 32
#
# 	ANN loss: 149.97776794433594
#
# hidden units number: 64
#
# 	ANN loss: 150.90585327148438
#
# hidden units number: 128
#
# 	ANN loss: 157.8280792236328
#
# hidden units number: 256
#
# 	ANN loss: 157.03109741210938
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 16346.912109375
#
# hidden units number: 8
#
# 	ANN loss: 692.6692504882812
#
# hidden units number: 16
#
# 	ANN loss: 144.78701782226562
#
# hidden units number: 32
#
# 	ANN loss: 141.8231658935547
#
# hidden units number: 64
#
# 	ANN loss: 141.2413787841797
#
# hidden units number: 128
#
# 	ANN loss: 146.08995056152344
#
# hidden units number: 256
#
# 	ANN loss: 147.48699951171875
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 11975.8720703125
#
# hidden units number: 8
#
# 	ANN loss: 846.1966552734375
#
# hidden units number: 16
#
# 	ANN loss: 195.71823120117188
#
# hidden units number: 32
#
# 	ANN loss: 177.81210327148438
#
# hidden units number: 64
#
# 	ANN loss: 179.205322265625
#
# hidden units number: 128
#
# 	ANN loss: 178.15707397460938
#
# hidden units number: 256
#
# 	ANN loss: 180.52500915527344
#
#
#  Optimal Hidden units: 64
#  ANN error: 171.32379150390625
#  Optimal λ: 2.3434343434343443
#  Linear Regression error: 183.4550711564694
#  Baseline error: 188.08126734754848
#
#
#  ***Outer Crossvalidation fold: 6/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11905.44140625
#
# hidden units number: 8
#
# 	ANN loss: 897.8553466796875
#
# hidden units number: 16
#
# 	ANN loss: 207.86395263671875
#
# hidden units number: 32
#
# 	ANN loss: 193.87501525878906
#
# hidden units number: 64
#
# 	ANN loss: 192.3562774658203
#
# hidden units number: 128
#
# 	ANN loss: 198.05677795410156
#
# hidden units number: 256
#
# 	ANN loss: 201.4385528564453
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 12355.181640625
#
# hidden units number: 8
#
# 	ANN loss: 958.08984375
#
# hidden units number: 16
#
# 	ANN loss: 184.34283447265625
#
# hidden units number: 32
#
# 	ANN loss: 163.3477783203125
#
# hidden units number: 64
#
# 	ANN loss: 161.07205200195312
#
# hidden units number: 128
#
# 	ANN loss: 173.59259033203125
#
# hidden units number: 256
#
# 	ANN loss: 176.46774291992188
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 16936.546875
#
# hidden units number: 8
#
# 	ANN loss: 799.232421875
#
# hidden units number: 16
#
# 	ANN loss: 184.6012420654297
#
# hidden units number: 32
#
# 	ANN loss: 147.72866821289062
#
# hidden units number: 64
#
# 	ANN loss: 147.47129821777344
#
# hidden units number: 128
#
# 	ANN loss: 146.6137237548828
#
# hidden units number: 256
#
# 	ANN loss: 146.35572814941406
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 17059.7890625
#
# hidden units number: 8
#
# 	ANN loss: 531.7417602539062
#
# hidden units number: 16
#
# 	ANN loss: 176.0762939453125
#
# hidden units number: 32
#
# 	ANN loss: 163.40823364257812
#
# hidden units number: 64
#
# 	ANN loss: 161.51071166992188
#
# hidden units number: 128
#
# 	ANN loss: 162.34544372558594
#
# hidden units number: 256
#
# 	ANN loss: 170.16566467285156
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 12224.048828125
#
# hidden units number: 8
#
# 	ANN loss: 3545.83349609375
#
# hidden units number: 16
#
# 	ANN loss: 190.81182861328125
#
# hidden units number: 32
#
# 	ANN loss: 158.89242553710938
#
# hidden units number: 64
#
# 	ANN loss: 160.58436584472656
#
# hidden units number: 128
#
# 	ANN loss: 168.27171325683594
#
# hidden units number: 256
#
# 	ANN loss: 169.1099090576172
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 17064.244140625
#
# hidden units number: 8
#
# 	ANN loss: 709.8175659179688
#
# hidden units number: 16
#
# 	ANN loss: 181.49415588378906
#
# hidden units number: 32
#
# 	ANN loss: 154.09490966796875
#
# hidden units number: 64
#
# 	ANN loss: 153.53076171875
#
# hidden units number: 128
#
# 	ANN loss: 151.00735473632812
#
# hidden units number: 256
#
# 	ANN loss: 157.7121124267578
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 17211.177734375
#
# hidden units number: 8
#
# 	ANN loss: 814.1022338867188
#
# hidden units number: 16
#
# 	ANN loss: 186.34246826171875
#
# hidden units number: 32
#
# 	ANN loss: 137.08517456054688
#
# hidden units number: 64
#
# 	ANN loss: 143.74240112304688
#
# hidden units number: 128
#
# 	ANN loss: 147.94056701660156
#
# hidden units number: 256
#
# 	ANN loss: 150.960205078125
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 11955.837890625
#
# hidden units number: 8
#
# 	ANN loss: 1296.707763671875
#
# hidden units number: 16
#
# 	ANN loss: 162.10498046875
#
# hidden units number: 32
#
# 	ANN loss: 149.24478149414062
#
# hidden units number: 64
#
# 	ANN loss: 148.50747680664062
#
# hidden units number: 128
#
# 	ANN loss: 152.7052764892578
#
# hidden units number: 256
#
# 	ANN loss: 155.00865173339844
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 12664.2236328125
#
# hidden units number: 8
#
# 	ANN loss: 881.589599609375
#
# hidden units number: 16
#
# 	ANN loss: 181.32879638671875
#
# hidden units number: 32
#
# 	ANN loss: 168.0804443359375
#
# hidden units number: 64
#
# 	ANN loss: 168.3722686767578
#
# hidden units number: 128
#
# 	ANN loss: 166.35040283203125
#
# hidden units number: 256
#
# 	ANN loss: 171.3682861328125
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 11862.267578125
#
# hidden units number: 8
#
# 	ANN loss: 780.0276489257812
#
# hidden units number: 16
#
# 	ANN loss: 179.7321014404297
#
# hidden units number: 32
#
# 	ANN loss: 164.27345275878906
#
# hidden units number: 64
#
# 	ANN loss: 156.73207092285156
#
# hidden units number: 128
#
# 	ANN loss: 158.72216796875
#
# hidden units number: 256
#
# 	ANN loss: 157.8754425048828
#
#
#  Optimal Hidden units: 64
#  ANN error: 154.63388061523438
#  Optimal λ: 2.666666666666668
#  Linear Regression error: 163.4825130867381
#  Baseline error: 179.3071655708322
#
#
#  ***Outer Crossvalidation fold: 7/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11844.9287109375
#
# hidden units number: 8
#
# 	ANN loss: 1534.7349853515625
#
# hidden units number: 16
#
# 	ANN loss: 179.1885223388672
#
# hidden units number: 32
#
# 	ANN loss: 162.73414611816406
#
# hidden units number: 64
#
# 	ANN loss: 161.75526428222656
#
# hidden units number: 128
#
# 	ANN loss: 164.15187072753906
#
# hidden units number: 256
#
# 	ANN loss: 169.07896423339844
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 16652.900390625
#
# hidden units number: 8
#
# 	ANN loss: 875.637451171875
#
# hidden units number: 16
#
# 	ANN loss: 166.75108337402344
#
# hidden units number: 32
#
# 	ANN loss: 143.33108520507812
#
# hidden units number: 64
#
# 	ANN loss: 142.37522888183594
#
# hidden units number: 128
#
# 	ANN loss: 146.4521942138672
#
# hidden units number: 256
#
# 	ANN loss: 152.1111297607422
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 17249.322265625
#
# hidden units number: 8
#
# 	ANN loss: 1465.8333740234375
#
# hidden units number: 16
#
# 	ANN loss: 175.2228240966797
#
# hidden units number: 32
#
# 	ANN loss: 164.92324829101562
#
# hidden units number: 64
#
# 	ANN loss: 157.3382110595703
#
# hidden units number: 128
#
# 	ANN loss: 164.5615997314453
#
# hidden units number: 256
#
# 	ANN loss: 167.20654296875
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 16866.607421875
#
# hidden units number: 8
#
# 	ANN loss: 1156.3558349609375
#
# hidden units number: 16
#
# 	ANN loss: 203.68284606933594
#
# hidden units number: 32
#
# 	ANN loss: 176.50543212890625
#
# hidden units number: 64
#
# 	ANN loss: 175.2450714111328
#
# hidden units number: 128
#
# 	ANN loss: 185.81729125976562
#
# hidden units number: 256
#
# 	ANN loss: 192.98614501953125
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 11807.7138671875
#
# hidden units number: 8
#
# 	ANN loss: 1345.5269775390625
#
# hidden units number: 16
#
# 	ANN loss: 178.8879852294922
#
# hidden units number: 32
#
# 	ANN loss: 161.68756103515625
#
# hidden units number: 64
#
# 	ANN loss: 162.04469299316406
#
# hidden units number: 128
#
# 	ANN loss: 165.57513427734375
#
# hidden units number: 256
#
# 	ANN loss: 165.8147735595703
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 11767.146484375
#
# hidden units number: 8
#
# 	ANN loss: 536.3928833007812
#
# hidden units number: 16
#
# 	ANN loss: 172.65380859375
#
# hidden units number: 32
#
# 	ANN loss: 160.3792724609375
#
# hidden units number: 64
#
# 	ANN loss: 163.87066650390625
#
# hidden units number: 128
#
# 	ANN loss: 167.15863037109375
#
# hidden units number: 256
#
# 	ANN loss: 169.13507080078125
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 17172.07421875
#
# hidden units number: 8
#
# 	ANN loss: 568.7117309570312
#
# hidden units number: 16
#
# 	ANN loss: 210.11801147460938
#
# hidden units number: 32
#
# 	ANN loss: 192.78868103027344
#
# hidden units number: 64
#
# 	ANN loss: 187.24038696289062
#
# hidden units number: 128
#
# 	ANN loss: 193.16880798339844
#
# hidden units number: 256
#
# 	ANN loss: 207.45362854003906
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 12765.7626953125
#
# hidden units number: 8
#
# 	ANN loss: 1273.4267578125
#
# hidden units number: 16
#
# 	ANN loss: 166.66464233398438
#
# hidden units number: 32
#
# 	ANN loss: 160.31787109375
#
# hidden units number: 64
#
# 	ANN loss: 163.6840362548828
#
# hidden units number: 128
#
# 	ANN loss: 165.52713012695312
#
# hidden units number: 256
#
# 	ANN loss: 173.7867889404297
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 12261.75
#
# hidden units number: 8
#
# 	ANN loss: 780.3486328125
#
# hidden units number: 16
#
# 	ANN loss: 189.2749481201172
#
# hidden units number: 32
#
# 	ANN loss: 151.9578857421875
#
# hidden units number: 64
#
# 	ANN loss: 151.97198486328125
#
# hidden units number: 128
#
# 	ANN loss: 150.17433166503906
#
# hidden units number: 256
#
# 	ANN loss: 155.3323516845703
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 12506.8603515625
#
# hidden units number: 8
#
# 	ANN loss: 529.5966796875
#
# hidden units number: 16
#
# 	ANN loss: 205.2365264892578
#
# hidden units number: 32
#
# 	ANN loss: 171.22329711914062
#
# hidden units number: 64
#
# 	ANN loss: 166.73341369628906
#
# hidden units number: 128
#
# 	ANN loss: 171.48634338378906
#
# hidden units number: 256
#
# 	ANN loss: 170.05299377441406
#
#
#  Optimal Hidden units: 64
#  ANN error: 135.6351318359375
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 142.87667732745967
#  Baseline error: 154.68076937030847
#
#
#  ***Outer Crossvalidation fold: 8/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 12362.9677734375
#
# hidden units number: 8
#
# 	ANN loss: 706.2088012695312
#
# hidden units number: 16
#
# 	ANN loss: 192.28326416015625
#
# hidden units number: 32
#
# 	ANN loss: 167.30343627929688
#
# hidden units number: 64
#
# 	ANN loss: 162.4147186279297
#
# hidden units number: 128
#
# 	ANN loss: 167.2457733154297
#
# hidden units number: 256
#
# 	ANN loss: 166.5702667236328
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 16454.861328125
#
# hidden units number: 8
#
# 	ANN loss: 1316.2662353515625
#
# hidden units number: 16
#
# 	ANN loss: 142.57513427734375
#
# hidden units number: 32
#
# 	ANN loss: 141.3289794921875
#
# hidden units number: 64
#
# 	ANN loss: 150.5570526123047
#
# hidden units number: 128
#
# 	ANN loss: 157.45684814453125
#
# hidden units number: 256
#
# 	ANN loss: 166.6915740966797
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 17269.498046875
#
# hidden units number: 8
#
# 	ANN loss: 786.747802734375
#
# hidden units number: 16
#
# 	ANN loss: 193.15109252929688
#
# hidden units number: 32
#
# 	ANN loss: 162.97898864746094
#
# hidden units number: 64
#
# 	ANN loss: 155.2607421875
#
# hidden units number: 128
#
# 	ANN loss: 154.42803955078125
#
# hidden units number: 256
#
# 	ANN loss: 159.689697265625
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 12606.234375
#
# hidden units number: 8
#
# 	ANN loss: 855.0877685546875
#
# hidden units number: 16
#
# 	ANN loss: 149.4866485595703
#
# hidden units number: 32
#
# 	ANN loss: 128.69386291503906
#
# hidden units number: 64
#
# 	ANN loss: 125.94727325439453
#
# hidden units number: 128
#
# 	ANN loss: 129.37960815429688
#
# hidden units number: 256
#
# 	ANN loss: 133.34657287597656
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 11986.9228515625
#
# hidden units number: 8
#
# 	ANN loss: 481.35797119140625
#
# hidden units number: 16
#
# 	ANN loss: 164.20880126953125
#
# hidden units number: 32
#
# 	ANN loss: 151.1004638671875
#
# hidden units number: 64
#
# 	ANN loss: 155.2975311279297
#
# hidden units number: 128
#
# 	ANN loss: 156.8669891357422
#
# hidden units number: 256
#
# 	ANN loss: 158.3004913330078
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 16688.447265625
#
# hidden units number: 8
#
# 	ANN loss: 861.576416015625
#
# hidden units number: 16
#
# 	ANN loss: 189.09939575195312
#
# hidden units number: 32
#
# 	ANN loss: 168.42771911621094
#
# hidden units number: 64
#
# 	ANN loss: 168.0840301513672
#
# hidden units number: 128
#
# 	ANN loss: 179.33636474609375
#
# hidden units number: 256
#
# 	ANN loss: 184.41519165039062
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 13106.123046875
#
# hidden units number: 8
#
# 	ANN loss: 1638.56640625
#
# hidden units number: 16
#
# 	ANN loss: 180.42434692382812
#
# hidden units number: 32
#
# 	ANN loss: 168.3949737548828
#
# hidden units number: 64
#
# 	ANN loss: 164.21238708496094
#
# hidden units number: 128
#
# 	ANN loss: 166.26966857910156
#
# hidden units number: 256
#
# 	ANN loss: 173.26657104492188
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 12154.0830078125
#
# hidden units number: 8
#
# 	ANN loss: 907.70458984375
#
# hidden units number: 16
#
# 	ANN loss: 193.59814453125
#
# hidden units number: 32
#
# 	ANN loss: 175.7946319580078
#
# hidden units number: 64
#
# 	ANN loss: 167.71875
#
# hidden units number: 128
#
# 	ANN loss: 175.364990234375
#
# hidden units number: 256
#
# 	ANN loss: 174.8639678955078
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 11891.921875
#
# hidden units number: 8
#
# 	ANN loss: 449.97955322265625
#
# hidden units number: 16
#
# 	ANN loss: 181.31495666503906
#
# hidden units number: 32
#
# 	ANN loss: 156.06663513183594
#
# hidden units number: 64
#
# 	ANN loss: 161.47134399414062
#
# hidden units number: 128
#
# 	ANN loss: 163.97845458984375
#
# hidden units number: 256
#
# 	ANN loss: 166.67807006835938
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 17127.611328125
#
# hidden units number: 8
#
# 	ANN loss: 915.5784301757812
#
# hidden units number: 16
#
# 	ANN loss: 207.4895477294922
#
# hidden units number: 32
#
# 	ANN loss: 180.45889282226562
#
# hidden units number: 64
#
# 	ANN loss: 181.31512451171875
#
# hidden units number: 128
#
# 	ANN loss: 180.91708374023438
#
# hidden units number: 256
#
# 	ANN loss: 183.00070190429688
#
#
#  Optimal Hidden units: 64
#  ANN error: 154.66726684570312
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 153.60293064850467
#  Baseline error: 177.6851737777089
#
#
#  ***Outer Crossvalidation fold: 9/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 11602.16015625
#
# hidden units number: 8
#
# 	ANN loss: 835.0661010742188
#
# hidden units number: 16
#
# 	ANN loss: 195.44912719726562
#
# hidden units number: 32
#
# 	ANN loss: 179.57554626464844
#
# hidden units number: 64
#
# 	ANN loss: 170.68243408203125
#
# hidden units number: 128
#
# 	ANN loss: 178.5113525390625
#
# hidden units number: 256
#
# 	ANN loss: 181.9663848876953
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 11865.1455078125
#
# hidden units number: 8
#
# 	ANN loss: 698.0452880859375
#
# hidden units number: 16
#
# 	ANN loss: 207.25140380859375
#
# hidden units number: 32
#
# 	ANN loss: 181.1943359375
#
# hidden units number: 64
#
# 	ANN loss: 178.893310546875
#
# hidden units number: 128
#
# 	ANN loss: 180.25961303710938
#
# hidden units number: 256
#
# 	ANN loss: 176.95315551757812
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 12311.0224609375
#
# hidden units number: 8
#
# 	ANN loss: 804.028076171875
#
# hidden units number: 16
#
# 	ANN loss: 205.75851440429688
#
# hidden units number: 32
#
# 	ANN loss: 156.1167755126953
#
# hidden units number: 64
#
# 	ANN loss: 157.6339874267578
#
# hidden units number: 128
#
# 	ANN loss: 158.3494873046875
#
# hidden units number: 256
#
# 	ANN loss: 159.99913024902344
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 11606.4951171875
#
# hidden units number: 8
#
# 	ANN loss: 2369.60498046875
#
# hidden units number: 16
#
# 	ANN loss: 189.1951141357422
#
# hidden units number: 32
#
# 	ANN loss: 171.39002990722656
#
# hidden units number: 64
#
# 	ANN loss: 173.3717041015625
#
# hidden units number: 128
#
# 	ANN loss: 177.3976287841797
#
# hidden units number: 256
#
# 	ANN loss: 177.0821990966797
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 12212.38671875
#
# hidden units number: 8
#
# 	ANN loss: 2532.837646484375
#
# hidden units number: 16
#
# 	ANN loss: 167.0791778564453
#
# hidden units number: 32
#
# 	ANN loss: 134.18386840820312
#
# hidden units number: 64
#
# 	ANN loss: 130.34039306640625
#
# hidden units number: 128
#
# 	ANN loss: 132.14866638183594
#
# hidden units number: 256
#
# 	ANN loss: 135.18690490722656
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 12133.6064453125
#
# hidden units number: 8
#
# 	ANN loss: 1281.6004638671875
#
# hidden units number: 16
#
# 	ANN loss: 188.08624267578125
#
# hidden units number: 32
#
# 	ANN loss: 155.36785888671875
#
# hidden units number: 64
#
# 	ANN loss: 155.7275390625
#
# hidden units number: 128
#
# 	ANN loss: 158.17442321777344
#
# hidden units number: 256
#
# 	ANN loss: 157.00006103515625
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 13071.89453125
#
# hidden units number: 8
#
# 	ANN loss: 1378.9554443359375
#
# hidden units number: 16
#
# 	ANN loss: 184.2198028564453
#
# hidden units number: 32
#
# 	ANN loss: 164.7926483154297
#
# hidden units number: 64
#
# 	ANN loss: 170.2197723388672
#
# hidden units number: 128
#
# 	ANN loss: 170.74697875976562
#
# hidden units number: 256
#
# 	ANN loss: 168.15164184570312
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 16501.859375
#
# hidden units number: 8
#
# 	ANN loss: 876.8516845703125
#
# hidden units number: 16
#
# 	ANN loss: 163.4315185546875
#
# hidden units number: 32
#
# 	ANN loss: 161.686767578125
#
# hidden units number: 64
#
# 	ANN loss: 157.7948760986328
#
# hidden units number: 128
#
# 	ANN loss: 169.8172149658203
#
# hidden units number: 256
#
# 	ANN loss: 175.7356719970703
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 11764.1708984375
#
# hidden units number: 8
#
# 	ANN loss: 834.3377685546875
#
# hidden units number: 16
#
# 	ANN loss: 173.82162475585938
#
# hidden units number: 32
#
# 	ANN loss: 151.6680908203125
#
# hidden units number: 64
#
# 	ANN loss: 154.06256103515625
#
# hidden units number: 128
#
# 	ANN loss: 163.5248260498047
#
# hidden units number: 256
#
# 	ANN loss: 165.42752075195312
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 12078.255859375
#
# hidden units number: 8
#
# 	ANN loss: 666.3988647460938
#
# hidden units number: 16
#
# 	ANN loss: 246.3358154296875
#
# hidden units number: 32
#
# 	ANN loss: 173.3516387939453
#
# hidden units number: 64
#
# 	ANN loss: 179.88604736328125
#
# hidden units number: 128
#
# 	ANN loss: 180.61143493652344
#
# hidden units number: 256
#
# 	ANN loss: 182.27935791015625
#
#
#  Optimal Hidden units: 64
#  ANN error: 150.6585235595703
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 164.65525492450607
#  Baseline error: 174.59217370253498
#
#
#  ***Outer Crossvalidation fold: 10/10
#
#  Inner Crossvalidation Fold: 1/10
# hidden units number: 1
#
# 	ANN loss: 17100.609375
#
# hidden units number: 8
#
# 	ANN loss: 1509.44482421875
#
# hidden units number: 16
#
# 	ANN loss: 198.74639892578125
#
# hidden units number: 32
#
# 	ANN loss: 178.74960327148438
#
# hidden units number: 64
#
# 	ANN loss: 174.57151794433594
#
# hidden units number: 128
#
# 	ANN loss: 174.47174072265625
#
# hidden units number: 256
#
# 	ANN loss: 185.15383911132812
#
#
#  Inner Crossvalidation Fold: 2/10
# hidden units number: 1
#
# 	ANN loss: 17031.466796875
#
# hidden units number: 8
#
# 	ANN loss: 682.7868041992188
#
# hidden units number: 16
#
# 	ANN loss: 180.8574981689453
#
# hidden units number: 32
#
# 	ANN loss: 180.01625061035156
#
# hidden units number: 64
#
# 	ANN loss: 177.49960327148438
#
# hidden units number: 128
#
# 	ANN loss: 180.2854461669922
#
# hidden units number: 256
#
# 	ANN loss: 184.70750427246094
#
#
#  Inner Crossvalidation Fold: 3/10
# hidden units number: 1
#
# 	ANN loss: 12464.787109375
#
# hidden units number: 8
#
# 	ANN loss: 879.479736328125
#
# hidden units number: 16
#
# 	ANN loss: 201.67138671875
#
# hidden units number: 32
#
# 	ANN loss: 194.0070037841797
#
# hidden units number: 64
#
# 	ANN loss: 191.79078674316406
#
# hidden units number: 128
#
# 	ANN loss: 190.69410705566406
#
# hidden units number: 256
#
# 	ANN loss: 195.56097412109375
#
#
#  Inner Crossvalidation Fold: 4/10
# hidden units number: 1
#
# 	ANN loss: 17053.958984375
#
# hidden units number: 8
#
# 	ANN loss: 2428.77392578125
#
# hidden units number: 16
#
# 	ANN loss: 173.23280334472656
#
# hidden units number: 32
#
# 	ANN loss: 159.30340576171875
#
# hidden units number: 64
#
# 	ANN loss: 158.87484741210938
#
# hidden units number: 128
#
# 	ANN loss: 159.95004272460938
#
# hidden units number: 256
#
# 	ANN loss: 164.74815368652344
#
#
#  Inner Crossvalidation Fold: 5/10
# hidden units number: 1
#
# 	ANN loss: 12393.00390625
#
# hidden units number: 8
#
# 	ANN loss: 543.1104736328125
#
# hidden units number: 16
#
# 	ANN loss: 179.70787048339844
#
# hidden units number: 32
#
# 	ANN loss: 158.13961791992188
#
# hidden units number: 64
#
# 	ANN loss: 157.04653930664062
#
# hidden units number: 128
#
# 	ANN loss: 168.3974151611328
#
# hidden units number: 256
#
# 	ANN loss: 175.71595764160156
#
#
#  Inner Crossvalidation Fold: 6/10
# hidden units number: 1
#
# 	ANN loss: 11649.08984375
#
# hidden units number: 8
#
# 	ANN loss: 801.2352294921875
#
# hidden units number: 16
#
# 	ANN loss: 154.52777099609375
#
# hidden units number: 32
#
# 	ANN loss: 160.0181121826172
#
# hidden units number: 64
#
# 	ANN loss: 152.4254608154297
#
# hidden units number: 128
#
# 	ANN loss: 155.2123565673828
#
# hidden units number: 256
#
# 	ANN loss: 158.7372589111328
#
#
#  Inner Crossvalidation Fold: 7/10
# hidden units number: 1
#
# 	ANN loss: 17268.30859375
#
# hidden units number: 8
#
# 	ANN loss: 593.6636352539062
#
# hidden units number: 16
#
# 	ANN loss: 156.4993896484375
#
# hidden units number: 32
#
# 	ANN loss: 129.26126098632812
#
# hidden units number: 64
#
# 	ANN loss: 133.23052978515625
#
# hidden units number: 128
#
# 	ANN loss: 136.6708526611328
#
# hidden units number: 256
#
# 	ANN loss: 134.64968872070312
#
#
#  Inner Crossvalidation Fold: 8/10
# hidden units number: 1
#
# 	ANN loss: 12613.38671875
#
# hidden units number: 8
#
# 	ANN loss: 593.638427734375
#
# hidden units number: 16
#
# 	ANN loss: 197.6326141357422
#
# hidden units number: 32
#
# 	ANN loss: 177.19065856933594
#
# hidden units number: 64
#
# 	ANN loss: 174.6036376953125
#
# hidden units number: 128
#
# 	ANN loss: 179.7635498046875
#
# hidden units number: 256
#
# 	ANN loss: 180.78282165527344
#
#
#  Inner Crossvalidation Fold: 9/10
# hidden units number: 1
#
# 	ANN loss: 12890.3212890625
#
# hidden units number: 8
#
# 	ANN loss: 694.91455078125
#
# hidden units number: 16
#
# 	ANN loss: 162.57106018066406
#
# hidden units number: 32
#
# 	ANN loss: 154.51747131347656
#
# hidden units number: 64
#
# 	ANN loss: 159.8721160888672
#
# hidden units number: 128
#
# 	ANN loss: 161.49766540527344
#
# hidden units number: 256
#
# 	ANN loss: 165.12330627441406
#
#
#  Inner Crossvalidation Fold: 10/10
# hidden units number: 1
#
# 	ANN loss: 12086.71875
#
# hidden units number: 8
#
# 	ANN loss: 835.6968994140625
#
# hidden units number: 16
#
# 	ANN loss: 202.27728271484375
#
# hidden units number: 32
#
# 	ANN loss: 180.08531188964844
#
# hidden units number: 64
#
# 	ANN loss: 169.45909118652344
#
# hidden units number: 128
#
# 	ANN loss: 172.11337280273438
#
# hidden units number: 256
#
# 	ANN loss: 173.48178100585938
#
#
#  Optimal Hidden units: 64
#  ANN error: 132.55160522460938
#  Optimal λ: 2.505050505050505
#  Linear Regression error: 131.74803021170376
#  Baseline error: 138.72496706126304

# %%
# show ANN vs Linear Regression
lower_bounds_al = [row[0] for row in CI_al_r]
upper_bounds_al = [row[1] for row in CI_al_r]
column_means_al = [sum(row) / len(row) for row in CI_al_r]
center_line1_al = np.mean(np.concatenate([lower_bounds_al, upper_bounds_al]))
x = np.arange(1,K+1)
plt.figure(figsize=(8, 4))
for x, start, end in zip(x, lower_bounds_al, upper_bounds_al):
    plt.bar(x, height=end-start, bottom=start, width = 0.2)
    
plt.scatter(np.arange(1, k+1), column_means_al, color='black', marker='o', label='Mean Value')
plt.axhline(center_line1_al, color='red', linestyle='--', label='mean')
plt.xlabel('K-Fold')
plt.ylabel('Confidence Interval')
plt.title('ANN vs Linear Regression')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('ANN vs Linear Regression Confidence Interval.pdf', dpi=1000)
plt.show()
plt.figure(figsize=(8, 4))
plt.plot(np.arange(1, k+1), p_al_r, marker='o', linestyle='-', color = 'red')
plt.xlabel('K-Fold')
plt.ylabel('P Value')
plt.title('ANN vs Linear Regression')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('ANN vs Linear Regression P Value.pdf', dpi=1000)
plt.show()

# show ANN vs Baseline
lower_bounds_ab = [row[0] for row in CI_ab_r]
upper_bounds_ab = [row[1] for row in CI_ab_r]
column_means_ab = [sum(row) / len(row) for row in CI_ab_r]
center_line1_ab = np.mean(np.concatenate([lower_bounds_ab,upper_bounds_ab]))
x = np.arange(1,K+1)
plt.figure(figsize=(8, 4))
for x, start, end in zip(x, lower_bounds_ab, upper_bounds_ab):
    plt.bar(x, height=end-start, bottom=start, width = 0.2)
    
plt.scatter(np.arange(1, k+1), column_means_ab, color='black', marker='o', label='Mean Value')
plt.axhline(center_line1_ab, color='red', linestyle='--', label='mean')
plt.xlabel('K-Fold')
plt.ylabel('Confidence Interval')
plt.title('ANN vs Baseline')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('regression ANN vs Baseline Confidence Interval.pdf', dpi=1000)
plt.show()
plt.figure(figsize=(8, 4))
plt.plot(np.arange(1, k+1), p_ab_r, marker='o', linestyle='-', color = 'red')
plt.xlabel('K-Fold')
plt.ylabel('P Value')
plt.title('ANN vs Baseline')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('regression ANN vs Baseline P Value.pdf', dpi=1000)
plt.show()

# show Linear Regression vs Baseline
lower_bounds_lb = [row[0] for row in CI_lb_r]
upper_bounds_lb = [row[1] for row in CI_lb_r]
column_means_lb = [sum(row) / len(row) for row in CI_lb_r]
center_line1_lb = np.mean(np.concatenate([lower_bounds_lb,upper_bounds_lb]))
x = np.arange(1,K+1)
plt.figure(figsize=(8, 4))
for x, start, end in zip(x, lower_bounds_lb, upper_bounds_lb):
    plt.bar(x, height=end-start, bottom=start, width = 0.2)
    
plt.scatter(np.arange(1, k+1), column_means_lb, color='black', marker='o', label='Mean Value')
plt.axhline(center_line1_lb, color='red', linestyle='--', label='mean')
plt.xlabel('K-Fold')
plt.ylabel('Confidence Interval')
plt.title('Linear Regression vs Baseline')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('Linear Regression vs Baseline Confidence Interval.pdf', dpi=1000)
plt.show()
plt.figure(figsize=(8, 4))
plt.plot(np.arange(1, k+1), p_lb_r, marker='o', linestyle='-', color = 'red')
plt.xlabel('K-Fold')
plt.ylabel('P Value')
plt.title('Linear Regression vs Baseline')
plt.xticks(np.arange(1, k+1, 1))
plt.savefig('Linear Regression vs Baseline P Value.pdf', dpi=1000)
plt.show()
